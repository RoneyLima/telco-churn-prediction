# %% [markdown]
# # Entendimento do Negócio
# **Projeto:** Telco Churn Prediction
# **Data:** 2026-08-15
# **Autor(es):** `<nome(s)>`
# **Versão:** `1.0`
# **Metodologia:** CRISP-DM + CRISP-ML(Q)
#
# ---
# > Este documento formaliza a fase de Entendimento do Negócio — a base do projeto. Todas as seções devem ser preenchidas e aprovadas por stakeholders de negócio e técnicos antes de avançar para a próxima fase. Revisite e atualize este documento sempre que o escopo ou os requisitos mudarem.

# %% [markdown]
# ## 1. Objetivos de Negócio
# *CRISP-DM: Determinar Objetivos de Negócio | CRISP-ML(Q): Entendimento do Negócio*
#
# ### 1.1 Contexto
# > Descreva a situação atual da organização, a unidade de negócio envolvida e o contexto que motivou este projeto. Inclua conhecimento de domínio relevante.
#
# `<descrição do contexto>`
#
# ---
#
# ### 1.2 Declaração do Problema de Negócio
# > Declare o problema claramente em termos de negócio. Evite jargão técnico. Qual dor, oportunidade ou decisão precisa ser apoiada?
#
# `<declaração do problema>`
#
# ---
#
# ### 1.3 Objetivos de Negócio
# > Liste os objetivos específicos e mensuráveis que a organização deseja alcançar. Cada objetivo deve ser acionável.
#
# | # | Objetivo | Responsável | Prioridade |
# |---|-----------|-------------|------------|
# | 1 | `<objetivo>` | `<responsável>` | Alta / Média / Baixa |
# | 2 | | | |
#
# ---
#
# ### 1.4 Critérios de Sucesso de Negócio
# > Defina os critérios que determinarão se o projeto teve sucesso **do ponto de vista de negócio**. Devem ser quantificáveis sempre que possível.
#
# | Critério | Métrica | Linha de Base Atual | Meta |
# |----------|---------|---------------------|------|
# | `<critério>` | `<métrica>` | `<linha de base>` | `<meta>` |
# |  |  |  |  |

# %% [markdown]
# ## 2. Avaliação da Situação
# *CRISP-DM: Avaliar Situação | CRISP-ML(Q): Entendimento do Negócio e dos Dados*
#
# ### 2.1 Inventário de Recursos
# > Liste todos os recursos disponíveis para o projeto: pessoas, dados, tecnologia e financeiros.
#
# **Pessoas**
#
# | Papel | Nome | Responsabilidade | Disponibilidade |
# |-------|------|------------------|-----------------|
# | Patrocinador do Projeto | `<nome>` | Aprovação de negócio & financiamento | `<% ou horas/semana>` |
# | Cientista de Dados | `<nome>` | Modelagem & análise | |
# | Engenheiro de Dados | `<nome>` | Pipelines de dados | |
# | Especialista de Domínio | `<nome>` | Conhecimento de negócio | |
# | Stakeholder | `<nome>` | Requisitos & validação | |
#
# **Dados & Tecnologia**
#
# | Recurso | Descrição | Localização / Acesso |
# |---------|-----------|----------------------|
# | `<fonte de dados>` | `<descrição>` | `<catalog.schema.table ou URL>` |
# | `<plataforma/ferramenta>` | `<descrição>` | |
#
# ---
#
# ### 2.2 Requisitos, Premissas e Restrições
#
# **Requisitos**
# > O que a solução deve entregar? (funcionais e não funcionais)
#
# - `<requisito>`
# - `<requisito>`
#
# **Premissas**
# > O que é assumido como verdadeiro sem verificação completa?
#
# - `<premissa>`
# - `<premissa>`
#
# **Restrições**
# > O que limita o escopo, a abordagem ou a entrega do projeto?
#
# | Tipo de Restrição | Descrição |
# |--------------------|----------|
# | Prazo | `<deadline / cadência de sprint>` |
# | Orçamento | `<teto orçamentário>` |
# | Legal / Regulatório | `<LGPD, GDPR, regulação setorial>` |
# | Técnico | `<limites de infraestrutura, ferramentas proibidas>` |
# | Dados | `<restrições de acesso, políticas de retenção>` |
#
# ---
#
# ### 2.3 Riscos e Planos de Contingência
#
# | Risco | Probabilidade (A/M/B) | Impacto (A/M/B) | Mitigação / Contingência |
# |-------|-----------------------|-----------------|--------------------------|
# | `<descrição do risco>` | M | A | `<ação de mitigação>` |
# | Indisponibilidade de dados | | | |
# | Expansão de escopo | | | |
#
# ---
#
# ### 2.4 Análise de Custo-Benefício
# > Forneça uma estimativa de alto nível dos custos do projeto vs. benefícios esperados.
#
# | Item | Custo Estimado | Benefício Esperado |
# |------|----------------|--------------------|
# | Esforço de desenvolvimento | `<valor>` | |
# | Infraestrutura | `<valor>` | |
# | **Total** | | `<ROI esperado / economia / receita>` |
#
# ---
#
# ### 2.5 Glossário
# > Defina termos específicos do domínio, abreviações e KPIs usados neste documento.
#
# | Termo | Definição |
# |-------|----------|
# | `<termo>` | `<definição>` |
# |  |  |

# %% [markdown]
# ## 3. Formulação da Tarefa de ML
# *CRISP-DM: Determinar Metas de Mineração de Dados | CRISP-ML(Q): Definição da Meta de ML*
#
# ### 3.1 Tradução para Problema de ML
# > Traduza o problema de negócio em uma tarefa concreta de aprendizado de máquina. Especifique o paradigma de ML e a variável-alvo.
#
# | Dimensão | Definição |
# |----------|----------|
# | Tipo de Tarefa de ML | `Classificação / Regressão / Clusterização / Previsão / Detecção de Anomalias / PLN / Visão Computacional / Outro` |
# | Paradigma de Aprendizado | `Supervisionado / Não supervisionado / Semissupervisionado / Autossupervisionado / Por Reforço` |
# | Variável-Alvo (y) | `<nome da coluna e descrição>` |
# | Unidade de Predição | `<o que uma linha/predição representa?>` |
# | Horizonte de Predição | `<tempo real / batch / T+N dias>` |
# | Variáveis de Entrada (X) | `<descrição de alto nível dos grupos de features>` |
#
# ---
#
# ### 3.2 Critérios de Sucesso de ML
# > Defina a performance mínima aceitável do modelo em métricas de ML mensuráveis. Deve ser acordado antes do início da modelagem.
#
# | Métrica | Limiar Mínimo | Meta Desejada | Justificativa |
# |---------|--------------|--------------|---------------|
# | `<ex.: F1-Score>` | `<ex.: 0,80>` | `<ex.: 0,90>` | `<por que esta métrica?>` |
# | `<ex.: RMSE>` | | | |
# | Latência de Inferência | `<ms / s>` | | `<requisito de SLA>` |
# | Throughput | `<registros/seg>` | | |
#
# > **Baseline a superar:** `<sistema baseado em regras / modelo ingênuo / performance humana / classificador aleatório>`
#
# ---
#
# ### 3.3 Valor Econômico e de Negócio do Modelo (opcional)
# > Quantifique o valor gerado por cada predição correta e o custo de cada tipo de erro.
#
# | Resultado da Predição | Consequência no Negócio | Valor/Custo Estimado |
# |-----------------------|------------------------|---------------------|
# | Verdadeiro Positivo | `<descrição>` | `<R$ / unidade>` |
# | Verdadeiro Negativo | `<descrição>` | `<R$ / unidade>` |
# | Falso Positivo (Erro Tipo I) | `<descrição>` | `<R$ / unidade>` |
# | Falso Negativo (Erro Tipo II) | `<descrição>` | `<R$ / unidade>` |
#
# ---
#
# ### 3.4 Saída e Consumo
# > Como as saídas do modelo serão consumidas? Descreva a interface, os consumidores e a frequência.
#
# | Aspecto | Descrição |
# |---------|----------|
# | Formato de saída | `<pontuação, rótulo, lista ranqueada, resposta de API, dashboard>` |
# | Consumidor principal | `<equipe, sistema, aplicação>` |
# | Frequência de consumo | `<tempo real, batch diário, sob demanda>` |
# | Ponto de integração | `<API REST, tabela Delta, dashboard BI, e-mail, etc.>` |

# %% [markdown]
# ## 4. Plano do Projeto
# *CRISP-DM: Produzir Plano do Projeto | CRISP-ML(Q): Planejamento do Projeto*
#
# ### 4.1 Roadmap de Fases
#
# | Fase | Descrição | Entregável | Duração Estimada | Responsável |
# |------|----------|-----------|-----------------|-------------|
# | 1. Entendimento do Negócio | Este documento | Documento de EN aprovado | `<N dias>` | |
# | 2. Entendimento dos Dados | AED, avaliação de qualidade de dados | Notebook de AED, relatório de qualidade | | |
# | 3. Preparação dos Dados | Engenharia de features, pipelines | Tabela de features, pipeline de dados | | |
# | 4. Modelagem | Treinamento, ajuste, avaliação | Modelo registrado, relatório de avaliação | | |
# | 5. Avaliação | Validação de negócio, backtesting | Avaliação vs. critérios de sucesso | | |
# | 6. Implantação | Serving, configuração de monitoramento | Endpoint implantado, dashboard de monitoramento | | |
# | 7. Monitoramento & Manutenção | Detecção de drift, gatilhos de retraining | Runbook de monitoramento | `<contínuo>` | |
#
# ---
#
# ### 4.2 Marcos e Datas-Chave
#
# | Marco | Data-Alvo | Status |
# |-------|-----------|--------|
# | Aprovação do Entendimento do Negócio | `<AAAA-MM-DD>` | `Pendente / Concluído` |
# | Acesso aos dados confirmado | | |
# | Modelo baseline validado | | |
# | Modelo aprovado para produção | | |
# | Implantação em produção | | |
# | Primeira revisão de performance | | |
#
# ---
#
# ### 4.3 Ferramentas e Stack Tecnológica
#
# | Categoria | Ferramenta / Plataforma | Observações |
# |-----------|------------------------|-------------|
# | Armazenamento de dados | `<Unity Catalog, Delta Lake, etc.>` | |
# | Computação | `<cluster Databricks, serverless>` | |
# | Rastreamento de experimentos | `<MLflow>` | |
# | Registro de modelos | `<Unity Catalog Model Registry>` | |
# | Orquestração | `<Lakeflow Jobs, Lakeflow SDP>` | |
# | Serving | `<Model Serving endpoint, batch>` | |
# | Monitoramento | `<Lakehouse Monitoring, customizado>` | |
# | Controle de versão | `<URL do repositório Git / branch>` | |
#
# ---
#
# ### 4.4 Cadência de Comunicação e Revisão
#
# | Reunião | Frequência | Participantes | Objetivo |
# |---------|-----------|--------------|----------|
# | Kickoff do projeto | Única | Todos os stakeholders | Alinhar escopo e plano |
# | Revisão de sprint | `<quinzenal>` | Equipe + patrocinador | Atualização de progresso |
# | Demo para stakeholders | `<mensal>` | Patrocinador + especialista de domínio | Validação de negócio |
# | Revisão pós-implantação | 30 / 60 / 90 dias | Todos | Avaliação de performance e impacto |

# %% [markdown]
# ## 5. Aprovação e Histórico de Revisões
#
# ### 5.1 Aprovação dos Stakeholders
# > Todas as partes devem revisar e aprovar este documento antes de o projeto avançar para a fase de Entendimento dos Dados.
#
# | Papel | Nome | Assinatura / Aprovação | Data |
# |-------|------|------------------------|------|
# | Patrocinador do Projeto | | | |
# | Responsável pelo Negócio | | | |
# | Líder de Ciência de Dados | | | |
# | Governança de Dados / Privacidade | | | |
#
# ---
#
# ### 5.2 Questões em Aberto e Itens de Ação
# > Documente questões não resolvidas e quem é responsável por respondê-las.
#
# | # | Questão / Ação | Responsável | Prazo | Status |
# |---|----------------|------------|-------|--------|
# | 1 | `<questão>` | `<nome>` | `<data>` | Em aberto |
# | 2 | | | | |
#
# ---
#
# ### 5.3 Histórico de Revisões
#
# | Versão | Data | Autor | Alterações |
# |--------|------|-------|------------|
# | 1.0 | `<AAAA-MM-DD>` | `<nome>` | Rascunho inicial |
# | | | | |
#
# ---
# *Template baseado em CRISP-DM (Chapman et al., 2000) e CRISP-ML(Q) (Studer et al., 2021).*
